# %%
import pandas as pd
import datetime
import random
import numpy as np


deviceInfo=[]
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300744G'])
deviceInfo.append(['戴尔电脑台式','台式机','Dell OPTIPLEX 5040MT','i5-6500 4G 1TB','1612989G'])
deviceInfo.append(['戴尔电脑台式','台式机','Dell OPTIPLEX 5040MT','i5-6500 4G 1TB','1717274G'])
deviceInfo.append(['戴尔电脑台式','台式机','Dell OPTIPLEX 5040MT','i5-6500 4G 1TB','1717280G'])
deviceInfo.append(['NEC投影机','投影设备','NP-ME360XC','3600流明','1213509G'])
deviceInfo.append(['美的变频空调机','空调设备','MDV-D71Q4/N1-C','嵌入式','1401123G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300863G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301262G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301262G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301262G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301262G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301262G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301262G'])
deviceInfo.append(['多媒体讲台','讲台中控','得实DS-606','得实DS-NET2K10IP-RF','1301342G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300873G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300874G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300879G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300887G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300906G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1300909G'])
deviceInfo.append(['NEC投影机','投影设备','NP-ME360XC','3600流明','1213511G'])
deviceInfo.append(['多媒体讲台','讲台中控','得实DS-606','得实DS-NET2K10IP-RF','1301345G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301149G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301151G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301155G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301160G'])
deviceInfo.append(['多媒体讲台','讲台中控','得实DS-606','得实DS-NET2K10IP-RF','1301406G'])
deviceInfo.append(['录播教室','其他设备','AVA A6（录播主机系统）','AVA ITS-1000（跟踪定位系统）','1514286G'])
deviceInfo.append(['戴尔电脑一体机','台式机','DELL Vosrto 360','i3-2120/4GB/500GB','1213140G'])
deviceInfo.append(['戴尔电脑一体机','台式机','DELL Vosrto 360','i3-2120/4GB/500GB','1213141G'])
deviceInfo.append(['戴尔电脑一体机','台式机','DELL Vosrto 360','i3-2120/4GB/500GB','1213148G'])
deviceInfo.append(['戴尔电脑一体机','台式机','DELL Vosrto 360','i3-2120/4GB/500GB','1213146G'])
deviceInfo.append(['戴尔电脑一体机','台式机','DELL Vosrto 360','i3-2120/4GB/500GB','1213157G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['语音系统','语音设备','上海桌越ABLE-EF2','ABLE-EF2','1301263G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301147G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301120G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301119G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301112G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301106G'])
deviceInfo.append(['惠普电脑','台式机','HP Compaq 6280 Pro','i5-2400/4G/500GB','1301099G'])

deal=['自行维修','自行维修','自行维修','自行维修','自行维修','课后更换备用设备','课后更换备用设备','课后更换备用设备','其他']
name=['欧阳童洁','吴茂林','张冬辉','戴俊琪']
head=['部门','设备名称','设备类型','设备型号','设备规格','设备序列号','解决方式','工单状态','问题描述','报修时间','响应时间','解决时间','创建人','修改时间','修改人','备注']
df=pd.DataFrame(columns=head)


def get3date():
    startTime=['2019/1/1 0:00:00','2019/02/14 0:00:00','2019/09/16 0:00:00']
    stopTime=['2019/1/17 0:00:00','2019/7/19 0:00:00','2019/12/31 0:00:00']
    randlist=[0,1,1,1,1,2,2,2]
    term=randlist[random.randint(0,len(randlist)-1)]
    start=time.mktime(time.strptime(startTime[term], "%Y/%m/%d %H:%M:%S"))
    end=time.mktime(time.strptime(stopTime[term], "%Y/%m/%d %H:%M:%S"))
    #时间戳转
    #time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(start))
    t=random.randint(start,end)    #在开始和结束时间戳中随机取出一个
    date_tuple=time.localtime(t)          #将时间戳生成时间元组
    data_list=list(date_tuple)
    data_list[3]=random.randint(8,16) 
    data_list[4]=0
    data_list[5]=0
    date_tuple=tuple(data_list)
    date=time.strftime("%Y/%m/%d %H:%M:%S",date_tuple)  #将时间元组转成格式化字符串（1976-05-21）
    d1 = datetime.datetime.strptime(date,'%Y/%m/%d %H:%M:%S')
    pdays=int(np.floor(abs(np.random.normal(0,1.5))))
    d2 = d1 + datetime.timedelta(days =pdays)
    date2=d2.strftime("%Y/%m/%d %H:%M:%S")
    t2=time.mktime(time.strptime(date2, "%Y/%m/%d %H:%M:%S"))
    date2_tuple=time.localtime(t2)
    data_list=list(date2_tuple)
    if pdays>0:
        data_list[3]=random.randint(8,16) 
    date2_tuple=tuple(data_list)
    date2=time.strftime("%Y/%m/%d %H:%M:%S",date2_tuple)    
    data_list[4]=random.randint(0,59) 
    data_list[5]=random.randint(0,59) 
    date2_tuple=tuple(data_list)
    date3=time.strftime("%Y/%m/%d %H:%M:%S",date2_tuple)  
    return [date,date2,date3,pdays]

def getLine():
    rdev=random.randint(0,len(deviceInfo)-1)
    times=get3date()
    name1=name[random.randint(0,len(name)-1)]
    if times[3]==0:
        name2=name1
    else:
        name2=name[random.randint(0,len(name)-1)]
    lineList=['翔安四号楼']
    lineList.append(deviceInfo[rdev][0])
    lineList.append(deviceInfo[rdev][1])
    lineList.append(deviceInfo[rdev][2])
    lineList.append(deviceInfo[rdev][3])
    lineList.append(deviceInfo[rdev][4])
    lineList.append(deal[random.randint(0,len(deal)-1)])
    lineList.append('已解决')
    lineList.append('')
    lineList.append(times[0])
    lineList.append('')
    lineList.append(times[1])
    lineList.append(name1)
    lineList.append(times[2])
    lineList.append(name2)
    lineList.append('')
    return lineList

# %%
a=pd.DataFrame(columns=head)
for i in range(0,131):
    a.loc[i]=getLine()
a
# Out:
#         部门     设备名称  设备类型                  设备型号                  设备规格  \
# 0    翔安四号楼   戴尔电脑台式   台式机  Dell OPTIPLEX 5040MT        i5-6500 4G 1TB
# 1    翔安四号楼    多媒体讲台  讲台中控              得实DS-606     得实DS-NET2K10IP-RF
# 2    翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 3    翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 4    翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 5    翔安四号楼  美的变频空调机  空调设备        MDV-D71Q4/N1-C                   嵌入式
# 6    翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 7    翔安四号楼  戴尔电脑一体机   台式机       DELL Vosrto 360     i3-2120/4GB/500GB
# 8    翔安四号楼  美的变频空调机  空调设备        MDV-D71Q4/N1-C                   嵌入式
# 9    翔安四号楼   戴尔电脑台式   台式机  Dell OPTIPLEX 5040MT        i5-6500 4G 1TB
# 10   翔安四号楼     惠普电脑   台式机    HP Compaq 6280 Pro      i5-2400/4G/500GB
# 11   翔安四号楼    多媒体讲台  讲台中控              得实DS-606     得实DS-NET2K10IP-RF
# 12   翔安四号楼     惠普电脑   台式机    HP Compaq 6280 Pro      i5-2400/4G/500GB
# 13   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 14   翔安四号楼     惠普电脑   台式机    HP Compaq 6280 Pro      i5-2400/4G/500GB
# 15   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 16   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 17   翔安四号楼  戴尔电脑一体机   台式机       DELL Vosrto 360     i3-2120/4GB/500GB
# 18   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 19   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 20   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 21   翔安四号楼   戴尔电脑台式   台式机  Dell OPTIPLEX 5040MT        i5-6500 4G 1TB
# 22   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 23   翔安四号楼     惠普电脑   台式机    HP Compaq 6280 Pro      i5-2400/4G/500GB
# 24   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
# 25   翔安四号楼     惠普电脑   台式机    HP Compaq 6280 Pro      i5-2400/4G/500GB
# 26   翔安四号楼     语音系统  语音设备          上海桌越ABLE-EF2              ABLE-EF2
#
# 104  2019/05/05 12:00:00  欧阳童洁  2019/05/05 12:35:59   戴俊琪
# 105  2019/10/07 12:00:00   吴茂林  2019/10/07 12:09:27   戴俊琪
# 106  2019/01/10 08:00:00   吴茂林  2019/01/10 08:26:54   张冬辉
# 107  2019/03/24 16:00:00   戴俊琪  2019/03/24 16:31:45  欧阳童洁
# 108  2019/03/21 08:00:00   吴茂林  2019/03/21 08:10:32   张冬辉
# 109  2019/11/05 09:00:00   张冬辉  2019/11/05 09:20:00   戴俊琪
# 110  2019/12/02 12:00:00   戴俊琪  2019/12/02 12:15:04   吴茂林
# 111  2019/02/17 11:00:00   张冬辉  2019/02/17 11:10:06   张冬辉
# 112  2019/07/13 13:00:00   张冬辉  2019/07/13 13:34:49   张冬辉
# 113  2019/05/05 13:00:00  欧阳童洁  2019/05/05 13:34:01   吴茂林
# 114  2019/12/12 13:00:00   戴俊琪  2019/12/12 13:38:28   戴俊琪
# 115  2019/05/20 15:00:00   戴俊琪  2019/05/20 15:17:40   戴俊琪
# 116  2019/03/23 08:00:00   吴茂林  2019/03/23 08:09:47  欧阳童洁
# 117  2019/06/19 11:00:00   张冬辉  2019/06/19 11:18:33   吴茂林
# 118  2019/11/20 16:00:00   张冬辉  2019/11/20 16:25:12   吴茂林
# 119  2019/10/12 09:00:00   吴茂林  2019/10/12 09:00:46   吴茂林
# 120  2019/04/29 15:00:00   吴茂林  2019/04/29 15:02:28   戴俊琪
# 121  2019/03/06 09:00:00   吴茂林  2019/03/06 09:00:23   吴茂林
# 122  2019/11/08 12:00:00   戴俊琪  2019/11/08 12:14:56  欧阳童洁
# 123  2019/01/10 13:00:00   张冬辉  2019/01/10 13:02:17   戴俊琪
# 124  2019/11/16 09:00:00   张冬辉  2019/11/16 09:18:10   张冬辉
# 125  2019/03/13 08:00:00   戴俊琪  2019/03/13 08:26:35   吴茂林
# 126  2019/03/30 16:00:00   戴俊琪  2019/03/30 16:23:35   戴俊琪
# 127  2019/10/28 12:00:00   吴茂林  2019/10/28 12:03:36  欧阳童洁
# 128  2019/09/29 08:00:00  欧阳童洁  2019/09/29 08:43:33  欧阳童洁
# 129  2019/06/22 08:00:00   张冬辉  2019/06/22 08:04:46   吴茂林
# 130  2019/01/12 10:00:00  欧阳童洁  2019/01/12 10:12:16  欧阳童洁
#
# [131 rows x 16 columns]

# %%
a=pd.DataFrame(columns=head)
a.loc[0]=getLine()
a.loc[1]=getLine()
a
# Out:
#       部门  设备名称  设备类型          设备型号      设备规格     设备序列号  解决方式 工单状态 问题描述  \
# 0  翔安四号楼  语音系统  语音设备  上海桌越ABLE-EF2  ABLE-EF2  1301263G  自行维修  已解决
# 1  翔安四号楼  语音系统  语音设备  上海桌越ABLE-EF2  ABLE-EF2  1301263G    其他  已解决
#
#                   报修时间 响应时间                 解决时间  创建人                 修改时间  \
# 0  2019/12/06 09:00:00       2019/12/06 09:00:00  吴茂林  2019/12/06 09:12:09
# 1  2019/03/27 15:00:00       2019/03/28 08:00:00  张冬辉  2019/03/28 08:22:50
#
#     修改人 备注
# 0   戴俊琪
# 1  欧阳童洁

# %%
randlist[random.randint(0,len(randlist)-1)]
# Out:
# 2

# %%
len(randlist)
# Out:
# 8
